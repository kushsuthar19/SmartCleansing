# %%
from dataclasses import dataclass
from typing import AsyncGenerator
import csv


@dataclass
class CSVParser:
    file_path: str

    async def parse(self) -> AsyncGenerator[list[dict],None]:
        with open(self.file_path,'r') as f:
           reader = csv.DictReader(f)
           records = [item for item in reader]

           yield records

# %%
csvparser = CSVParser("E:\\SmartCleansing\\Job_Placement_Data.csv")

# %%
for row in 
    csvparser.parse()
# Out:
# <async_generator object CSVParser.parse at 0x0000023772FFA040>
